# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %%
image_as_array = mpimg.imread(r"E:\study materials\python\02 Machine Learning - Udemy\UNZIP_FOR_NOTEBOOKS_FINAL\DATA\palm_trees.jpg")

# %%
image_as_array
# Out:
# array([[[ 25,  89, 127],
#         [ 25,  89, 127],
#         [ 25,  89, 127],
#         ...,
#         [ 23,  63,  99],
#         [ 51,  91, 127],
#         [ 50,  90, 126]],
#
#        [[ 25,  89, 127],
#         [ 25,  89, 127],
#         [ 25,  89, 127],
#         ...,
#         [ 31,  71, 107],
#         [ 48,  88, 124],
#         [ 47,  90, 125]],
#
#        [[ 25,  89, 127],
#         [ 25,  89, 127],
#         [ 25,  89, 127],
#         ...,
#         [ 39,  79, 115],
#         [ 42,  85, 120],
#         [ 44,  88, 123]],
#
#        ...,
#
#        [[  4,   4,   6],
#         [  4,   4,   6],
#         [  4,   4,   6],
#         ...,
#         [  9,   9,  11],
#         [  9,   9,  11],
#         [  9,   9,  11]],
#
#        [[  3,   3,   5],
#         [  3,   3,   5],
#         [  3,   3,   5],
#         ...,
#         [  8,   8,  10],
#         [  8,   8,  10],
#         [  8,   8,  10]],
#
#        [[  4,   4,   6],
#         [  4,   4,   6],
#         [  4,   4,   6],
# ...

# %%
image_as_array.shape
# Out:
# (1401, 934, 3)

# %%
plt.figure(dpi=200)
plt.imshow(image_as_array)

# %%
h,w,c = image_as_array.shape

# %%
h
# Out:
# 1401

# %%
w
# Out:
# 934

# %%
c
# Out:
# 3

# %%
image_as_array_2d = image_as_array.reshape(h*w,c)

# %%
image_as_array_2d
# Out:
# array([[ 25,  89, 127],
#        [ 25,  89, 127],
#        [ 25,  89, 127],
#        ...,
#        [  9,   9,  11],
#        [ 10,  10,  12],
#        [ 10,  10,  12]], dtype=uint8)

# %%
from sklearn.cluster import KMeans

# %%
model = KMeans(n_clusters=6)

# %%
labels = model.fit_predict(image_as_array_2d)

# %%
labels
# Out:
# array([3, 3, 3, ..., 0, 0, 0])

# %%
model.cluster_centers_
# Out:
# array([[  2.75553834,   2.5743035 ,   3.69915959],
#        [137.255246  , 143.90425481, 143.80112291],
#        [219.17427062, 135.05790563,  46.2922968 ],
#        [ 71.13660651, 109.27634571, 137.68652032],
#        [192.25863156, 154.51121673, 108.6858104 ],
#        [ 67.23934039,  61.52235727,  61.98350962]])

# %%
rgb_codes = model.cluster_centers_.round(0).astype(int)

# %%
rgb_codes
# Out:
# array([[  3,   3,   4],
#        [137, 144, 144],
#        [219, 135,  46],
#        [ 71, 109, 138],
#        [192, 155, 109],
#        [ 67,  62,  62]])

# %%
labels
# Out:
# array([3, 3, 3, ..., 0, 0, 0])

# %%
rgb_codes[labels]
# Out:
# array([[ 71, 109, 138],
#        [ 71, 109, 138],
#        [ 71, 109, 138],
#        ...,
#        [  3,   3,   4],
#        [  3,   3,   4],
#        [  3,   3,   4]])

# %%
quantized_image = np.reshape(rgb_codes[labels],(h,w,c))

# %%
quantized_image
# Out:
# array([[[ 71, 109, 138],
#         [ 71, 109, 138],
#         [ 71, 109, 138],
#         ...,
#         [ 67,  62,  62],
#         [ 71, 109, 138],
#         [ 71, 109, 138]],
#
#        [[ 71, 109, 138],
#         [ 71, 109, 138],
#         [ 71, 109, 138],
#         ...,
#         [ 67,  62,  62],
#         [ 71, 109, 138],
#         [ 71, 109, 138]],
#
#        [[ 71, 109, 138],
#         [ 71, 109, 138],
#         [ 71, 109, 138],
#         ...,
#         [ 71, 109, 138],
#         [ 71, 109, 138],
#         [ 71, 109, 138]],
#
#        ...,
#
#        [[  3,   3,   4],
#         [  3,   3,   4],
#         [  3,   3,   4],
#         ...,
#         [  3,   3,   4],
#         [  3,   3,   4],
#         [  3,   3,   4]],
#
#        [[  3,   3,   4],
#         [  3,   3,   4],
#         [  3,   3,   4],
#         ...,
#         [  3,   3,   4],
#         [  3,   3,   4],
#         [  3,   3,   4]],
#
#        [[  3,   3,   4],
#         [  3,   3,   4],
#         [  3,   3,   4],
# ...

# %%
plt.imshow(quantized_image)
